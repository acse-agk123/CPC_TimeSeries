# %%
import numpy as np
import matplotlib.pyplot as plt

# from benchmark_model import benchmark_model

import pandas as pd

# %%
from train import train_model

# %%
# convert csv to pd df

df = pd.read_csv('data/^HSI.csv')
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     1986-12-31   2568.300049   2568.300049   2568.300049   2568.300049
# 1     1987-01-01           NaN           NaN           NaN           NaN
# 2     1987-01-02   2540.100098   2540.100098   2540.100098   2540.100098
# 3     1987-01-05   2552.399902   2552.399902   2552.399902   2552.399902
# 4     1987-01-06   2583.899902   2583.899902   2583.899902   2583.899902
# ...          ...           ...           ...           ...           ...
# 7658  2016-12-22  21800.220703  21822.179688  21594.580078  21636.199219
# 7659  2016-12-23  21553.779297  21601.070313  21491.830078  21574.759766
# 7660  2016-12-28  21562.699219  21811.960938  21488.820313  21754.740234
# 7661  2016-12-29  21591.039063  21810.400391  21587.070313  21790.910156
# 7662  2016-12-30  21818.910156  22069.619141  21818.910156  22000.560547
#
#          Adj Close        Volume
# 0      2568.300049  0.000000e+00
# 1              NaN           NaN
# 2      2540.100098  0.000000e+00
# 3      2552.399902  0.000000e+00
# 4      2583.899902  0.000000e+00
# ...            ...           ...
# 7658  21636.199219  1.434736e+09
# 7659  21574.759766  1.775512e+09
# 7660  21754.740234  2.173240e+09
# 7661  21790.910156  1.875142e+09
# 7662  22000.560547  2.396676e+09
#
# [7663 rows x 7 columns]

# %%
df = df.drop(['Adj Close'], axis=1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     1986-12-31   2568.300049   2568.300049   2568.300049   2568.300049
# 1     1987-01-01           NaN           NaN           NaN           NaN
# 2     1987-01-02   2540.100098   2540.100098   2540.100098   2540.100098
# 3     1987-01-05   2552.399902   2552.399902   2552.399902   2552.399902
# 4     1987-01-06   2583.899902   2583.899902   2583.899902   2583.899902
# ...          ...           ...           ...           ...           ...
# 7658  2016-12-22  21800.220703  21822.179688  21594.580078  21636.199219
# 7659  2016-12-23  21553.779297  21601.070313  21491.830078  21574.759766
# 7660  2016-12-28  21562.699219  21811.960938  21488.820313  21754.740234
# 7661  2016-12-29  21591.039063  21810.400391  21587.070313  21790.910156
# 7662  2016-12-30  21818.910156  22069.619141  21818.910156  22000.560547
#
#             Volume
# 0     0.000000e+00
# 1              NaN
# 2     0.000000e+00
# 3     0.000000e+00
# 4     0.000000e+00
# ...            ...
# 7658  1.434736e+09
# 7659  1.775512e+09
# 7660  2.173240e+09
# 7661  1.875142e+09
# 7662  2.396676e+09
#
# [7663 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.columns = ['time', 'open', 'high', 'low', 'close', 'volume']
df['time'] = pd.to_datetime(df['time'], format='%Y-%m-%d')
df.set_index('time', inplace=True)
df
# Out:
#                     open          high           low         close  \
# time
# 1986-12-31   2568.300049   2568.300049   2568.300049   2568.300049
# 1987-01-01           NaN           NaN           NaN           NaN
# 1987-01-02   2540.100098   2540.100098   2540.100098   2540.100098
# 1987-01-05   2552.399902   2552.399902   2552.399902   2552.399902
# 1987-01-06   2583.899902   2583.899902   2583.899902   2583.899902
# ...                  ...           ...           ...           ...
# 2016-12-22  21800.220703  21822.179688  21594.580078  21636.199219
# 2016-12-23  21553.779297  21601.070313  21491.830078  21574.759766
# 2016-12-28  21562.699219  21811.960938  21488.820313  21754.740234
# 2016-12-29  21591.039063  21810.400391  21587.070313  21790.910156
# 2016-12-30  21818.910156  22069.619141  21818.910156  22000.560547
#
#                   volume
# time
# 1986-12-31  0.000000e+00
# 1987-01-01           NaN
# 1987-01-02  0.000000e+00
# 1987-01-05  0.000000e+00
# 1987-01-06  0.000000e+00
# ...                  ...
# 2016-12-22  1.434736e+09
# 2016-12-23  1.775512e+09
# 2016-12-28  2.173240e+09
# 2016-12-29  1.875142e+09
# 2016-12-30  2.396676e+09
#
# [7663 rows x 5 columns]

# %%
df.shape
# Out:
# (7663, 5)

# %%
df.to_csv('resources/time_series_data.csv')

# %%
train_model(
    epochs=10,
    batch_size=32,
    output_dir='models/timeseries',
    code_size=128,
    learning_rate=1e-3,
    terms=4,
    predict_terms=4,
    window_size=64,
    num_features=5
)
# Out:
# Preparing data...
# Creating dataset...
# Dataset created.
# Creating dataset...
# Dataset created.
# Data preparation took 0.06 seconds
# Preparing the model...
# Defining encoder model...
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 5, 1)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 5, 64)      │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 5, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 64, 5, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 5, 64)      │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 5, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 64, 5, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 5, 64)      │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 5, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 64, 5, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 5, 64)      │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64, 5, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 64, 5, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 20480)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     5,243,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_embedding (Dense)       │ (None, 128)            │        32,896 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,389,504 (20.56 MB)
#  Trainable params: 5,388,480 (20.56 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Defining the rest of the model...
# Defining CPC layer for loss computation...
# Creating CPC model...
# Compiling the model...
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 4, 64, 5,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 4, 128)    │          0 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ar_context (GRU)    │ (None, 256)       │    296,448 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_t_0 (Dense)       │ (None, 128)       │     32,896 │ ar_context[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_t_1 (Dense)       │ (None, 128)       │     32,896 │ ar_context[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_t_2 (Dense)       │ (None, 128)       │     32,896 │ ar_context[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_t_3 (Dense)       │ (None, 128)       │     32,896 │ ar_context[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 4, 64, 5,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 4, 128)    │          0 │ z_t_0[0][0],      │
# │                     │                   │            │ z_t_1[0][0],      │
# │                     │                   │            │ z_t_2[0][0],      │
# │                     │                   │            │ z_t_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 4, 128)    │          0 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cpc_layer           │ (None, 1)         │          0 │ lambda_1[0][0],   │
# │ (CPCLayer)          │                   │            │ lambda_2[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 428,032 (1.63 MB)
#  Trainable params: 428,032 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Setting up callbacks...
# Starting model training...
# Calling model.fit...
# Epoch 1 started at 2024-06-19 18:46:37
# Epoch 1/10

# %%
# # Call the train_model function
# train_model(
#     epochs=10,
#     batch_size=32,
#     output_dir='models/64x64',
#     code_size=128,
#     lr=1e-3,
#     terms=4,
#     predict_terms=4,
#     image_size=64,
#     color=True
# )

# %%
# benchmark_model(
#         encoder_path='models/64x64/encoder.h5',
#         epochs=15,
#         batch_size=64,
#         output_dir='models/64x64',
#         lr=1e-3,
#         image_size=64,
#         color=True
#     )
